# %%
import openai

# %%
from openai import OpenAI

# %%
client = OpenAI()

# %%
import os

# %%
response = client.chat.completions.create(
    model='gpt-4o',
    messages=[{"role":"user", "content": "is it too late to join the course?"}]
)

# %%
response.choices[0].message.content
# Out:
# "I'm not sure which course you're referring to, as there are countless courses with varying schedules and deadlines. To determine if it's too late to join a specific course, you should:\n\n1. **Check the Course Website:** Visit the official page for the course to find information on enrollment deadlines.\n   \n2. **Contact the Instructor or Institution:** Reach out directly to the course provider to inquire about the possibility of late enrollment.\n\n3. **Look for Enrollment Periods:** Some courses have multiple start dates throughout the year.\n\n4. **Explore Waitlists:** If a course is full or closed for enrollment, check if there is a waitlist option.\n\n5. **Consider Online Alternatives:** If it is too late to join a particular course, there might be online versions or similar courses available that have more flexible enrollment policies.\n\nIf you provide more details about the course, I might be able to offer more specific advice."
